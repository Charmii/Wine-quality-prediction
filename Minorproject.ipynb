# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('winequality-red.csv')
#Add your own path

# %%
print(dataset.info())
print(dataset.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB
# None
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# ...

# %%
dataset.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
#No null values hence no need to remove columns
#EDA 
print('Histogram 1:');
#Histograms:
fig = plt.figure(figsize = (6,4))
sns.distplot(dataset['fixed acidity'],color = 'green',kde = False );
plt.title('Histogram for Fixed Acidity');
plt.xlabel('Fixed Acidity');
fig = plt.figure(figsize = (6,4))
sns.kdeplot(dataset['fixed acidity'],color = 'green',shade = True)
plt.title('Kdeplot for Fixed Acidity');
plt.xlabel('Fixed Acidity');
# Out:
# Histogram 1:

# %%
print('Histogram 2:');
fig = plt.figure(figsize = (6,4))

sns.distplot(dataset['volatile acidity'],color = 'red', kde = False);
plt.xlabel('Volatile acidity');
plt.title('Histogram for Volatile Acidity');
fig = plt.figure(figsize = (6,4))
sns.kdeplot(dataset['volatile acidity'],color = 'red',shade = True)
plt.title('Kdeplot for volatile acidity');
plt.xlabel('volatile acidity');
# Out:
# Histogram 2:

# %%
print('Histogram 3:');
fig = plt.figure(figsize = (6,4))
sns.distplot(dataset['citric acid'],color = 'Orange', kde = False);
plt.xlabel('citric acid');
plt.title('Histogram for citric acid')
fig = plt.figure(figsize = (6,4))
sns.kdeplot(dataset['citric acid'],color = 'Orange',shade = True)
plt.title('Kdeplot for citric acid');
plt.xlabel('citric acid');
# Out:
# Histogram 3:

# %%
print('Histogram 4:');
fig = plt.figure(figsize = (6,4))
sns.distplot(dataset['residual sugar'],color = 'Blue', kde = False);
plt.xlabel('residual sugar');
plt.title('Histogram for residual sugar');
fig = plt.figure(figsize = (6,4))
sns.kdeplot(dataset['residual sugar'],color = 'Blue',shade = True)
plt.title('Kdeplot for residual sugar');
plt.xlabel('residual sugar');
# Out:
# Histogram 4:

# %%
print('Histogram 5:');
fig = plt.figure(figsize = (6,4))
sns.distplot(dataset['chlorides'],color = 'Black', kde = False);
plt.xlabel('Chlorides');
plt.title('Histogram for Chlorides');
fig = plt.figure(figsize = (6,4))
sns.kdeplot(dataset['chlorides'],color = 'Black',shade = True)
plt.title('Kdeplot for chlorides');
plt.xlabel('chlorides');
# Out:
# Histogram 5:

# %%
print('Histogram 5:');
sns.distplot(dataset['free sulfur dioxide'],color = 'purple', kde = False);
plt.xlabel('free sulfur dioxide');
plt.title('Histogram for free sulfur dioxide');
fig = plt.figure(figsize = (6,4))
sns.kdeplot(dataset['free sulfur dioxide'],color = 'purple',shade = True)
plt.title('Kdeplot for free sulfur dioxide');
plt.xlabel('free sulfur dioxide');
# Out:
# Histogram 5:

# %%
print('Boxplot 1:')
sns.boxplot('quality', 'fixed acidity', data = dataset)
# Out:
# Boxplot 1:

# %%
print('Boxplot 2:')
sns.boxplot('quality', 'volatile acidity', data = dataset)
# Out:
# Boxplot 2:

# %%
print('Boxplot 3:')
sns.boxplot('quality', 'citric acid', data = dataset)
# Out:
# Boxplot 3:

# %%
print('Boxplot 4:')
sns.boxplot('quality', 'residual sugar', data = dataset)
#Large number of outliers as the difference between 25th and 75th percentile is very less.
# Out:
# Boxplot 4:

# %%
print('Boxplot 5:')
sns.boxplot('quality', 'chlorides', data = dataset)
#Large number of outliers as the difference between 25th and 75th percentile is very less.
# Out:
# Boxplot 5:

# %%
print('Boxplot 6:')
sns.boxplot('quality', 'free sulfur dioxide', data = dataset)
# Out:
# Boxplot 6:

# %%
print('Boxplot 7:')
sns.boxplot('quality', 'total sulfur dioxide', data = dataset)
# Out:
# Boxplot 7:

# %%
print('Boxplot 8:')

sns.boxplot('quality', 'density', data = dataset)
# Out:
# Boxplot 8:

# %%
print('Boxplot 9:')
sns.boxplot('quality', 'pH', data = dataset)
# Out:
# Boxplot 9:

# %%
print('Boxplot 10:')
sns.boxplot('quality', 'sulphates', data = dataset)
# Out:
# Boxplot 10:

# %%
print('Boxplot 11:')
sns.boxplot('quality', 'alcohol', data = dataset)
# Out:
# Boxplot 11:

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
sns.barplot(x = 'quality', y = 'fixed acidity', data = dataset)
#No effect

# %%
sns.barplot(x = 'quality', y = 'volatile acidity', data = dataset)
#Quality increases as volatile acidity decreses

# %%
sns.barplot(x = 'quality', y = 'citric acid', data = dataset)
#Quality increases as citric acid increases

# %%
sns.barplot(x = 'quality', y = 'residual sugar', data = dataset)
#Almost same for all qualities

# %%
sns.barplot(x = 'quality', y = 'chlorides', data = dataset)
#Chlorides decreases as quality increases

# %%
sns.barplot(x = 'quality', y = 'free sulfur dioxide', data = dataset)

# %%
sns.barplot(x = 'quality', y = 'total sulfur dioxide', data = dataset)

# %%
sns.barplot(x = 'quality', y = 'density', data = dataset)
#Same for all

# %%
sns.barplot(x = 'quality', y = 'pH', data = dataset)
#Almost same for all

# %%
sns.barplot(x = 'quality', y = 'sulphates', data = dataset)
#Increases as quality increases

# %%
sns.barplot(x = 'quality', y = 'alcohol', data = dataset)
#Increases as quality increases

# %%
sns.lmplot(x = 'free sulfur dioxide',y = 'total sulfur dioxide', data = dataset,hue = 'quality')
#Total sulfur dioxide is directly proportional to free sulfur dioxide

# %%
sns.lmplot(x = 'alcohol',y = 'density', data = dataset,hue = 'quality')
#Density is inversely proportional to alcohol

# %%
sns.jointplot(x = 'volatile acidity',y = 'citric acid', data = dataset, color = 'orange')

# %%
sns.jointplot(x = 'alcohol',y = 'density', data = dataset, color = 'purple')

# %%
sns.jointplot(x = 'residual sugar',y = 'sulphates', data = dataset, color = 'black')

# %%
dataset.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
sns.heatmap(dataset.corr())

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
dataset.drop(['pH','density'],axis = 1)
#Dropping irrelevant columns
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
sns.countplot(dataset['quality'])

# %%
reviews = []
for i in dataset['quality']:
    if i >= 1 and i <= 3:
        reviews.append('1')
    elif i >= 4 and i <= 7:
        reviews.append('2')
    elif i >= 8 and i <= 10:
        reviews.append('3')
dataset['Reviews'] = reviews

# %%
sns.countplot(dataset['Reviews'])

# %%
X = dataset.iloc[:,:-1].values
y = dataset['Reviews']
dataset.drop(['quality'],axis=1)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#Splitting test and training set using train_test_split
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,y,test_size = 0.25)

# %%
#Apllying KNN on training set 
from sklearn.neighbors import KNeighborsClassifier
c = KNeighborsClassifier(n_neighbors = 2)
c.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#                      weights='uniform')

# %%
predicted = c.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cmatrix = confusion_matrix(Y_test,predicted)
cmatrix
# Out:
# array([[  0,   3,   0],
#        [  0, 388,   1],
#        [  0,   8,   0]], dtype=int64)

# %%
np.unique(predicted)
# Out:
# array(['2', '3'], dtype=object)

# %%
dataset.quality.value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
from sklearn.metrics import classification_report,accuracy_score
print(classification_report(Y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         3
#            2       0.97      1.00      0.98       389
#            3       0.00      0.00      0.00         8
#
#     accuracy                           0.97       400
#    macro avg       0.32      0.33      0.33       400
# weighted avg       0.95      0.97      0.96       400
# C:\Users\Charmi Shah\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
from sklearn import metrics 
print(metrics.accuracy_score(Y_test,predicted))
# Out:
# 0.97
